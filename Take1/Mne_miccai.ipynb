# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mne

# %matplotlib qt
print(mne.channels.get_builtin_montages())
# # output:
# ['standard_1005',
#  'standard_1020',
#  'standard_alphabetic',
#  'standard_postfixed',
#  'standard_prefixed',
#  'standard_primed',
#  'biosemi16',
#  'biosemi32',
#  'biosemi64',
#  'biosemi128',
#  'biosemi160',
#  'biosemi256',
#  'easycap-M1',
#  'easycap-M10',
#  'EGI_256',
#  'GSN-HydroCel-32',
#  'GSN-HydroCel-64_1.0',
#  'GSN-HydroCel-65_1.0',
#  'GSN-HydroCel-128',
#  'GSN-HydroCel-129',
#  'GSN-HydroCel-256',
#  'GSN-HydroCel-257',
#  'mgh60',
#  'mgh70',
#  'artinis-octamon',
#  'artinis-brite23',
#  'brainproducts-RNP-BA-128']
int64_montage = mne.channels.make_standard_montage('standard_1020')
int64_montage.plot()
import mne

paper_chs = ['AF3','AF4','AF7','AF8','AFz','C1','C2','C3','C4','C5','C6','CP1','CP2','CP3','CP4','CP5','CP6','CPz','Cz','F1','F2','F3','F4','F5','F6','F7','F8','FC1','FC2','FC3','FC4','FC5','FC6','FCz','FT10','FT7','FT8','FT9','Fp1','Fp2','O1','O2','Oz','P1','P2','P3','P4','P5','P6','P7','P8','PO3','PO4','PO7','PO8','POz','Pz','T7','T8','TP10','TP7','TP8','TP9']

# montage = mne.channels.make_standard_montage('biosemi64')
ch_pos = int64_montage.get_positions()['ch_pos']
ch_names = list(ch_pos.keys())
# print(f"原始通道数: {len(ch_names)}")
# print(ch_names)

sorted_names = sorted(ch_names)
print(f"\n按字母排序后的通道数: {len(sorted_names)}")
print(sorted_names)




#标准 'AF3', 'AF4', 'AF7', 'AF8', 'AFz', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'CP1', 'CP2', 'CP3', 'CP4', 'CP5', 'CP6', 'CPz', 'Cz', 'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'FC1', 'FC2', 'FC3', 'FC4', 'FC5', 'FC6', 'FCz',         'FT7', 'FT8',        'Fp1', 'Fp2', 'Fpz', 'Fz', 'Iz', 'O1', 'O2', 'Oz', 'P1', 'P10', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'PO3', 'PO4', 'PO7', 'PO8', 'POz', 'Pz', 'T7', 'T8', 'TP7',         'TP8']
# 论文'AF3', 'AF4', 'AF7', 'AF8', 'AFz', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'CP1', 'CP2', 'CP3', 'CP4', 'CP5', 'CP6', 'CPz', 'Cz', 'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'FC1', 'FC2', 'FC3', 'FC4', 'FC5', 'FC6', 'FCz', 'FT10', 'FT7', 'FT8', 'FT9', 'Fp1', 'Fp2',                    'O1', 'O2', 'Oz', 'P1',        'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8',       'PO3', 'PO4', 'PO7', 'PO8', 'POz', 'Pz', 'T7', 'T8', 'TP10', 'TP7', 'TP8', 'TP9'

#论文顺序
#'Fp1', 'Fp2', 'AF7', 'AF3', 'AFz', 'AF4', 'AF8', 'F7', 'F5', 'F3', 'F1', 'F2', 'F4', 'F6', 'F8', 'FT9', 'FT7', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'FT8', 'FT10',
# 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP9', 'TP7', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'TP8', 'TP10',
#  'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO3', 'POz', 'PO4', 'PO8', 'O1', 'Oz', 'O2'
plt.show()
# Out:
# ['standard_1005', 'standard_1020', 'standard_alphabetic', 'standard_postfixed', 'standard_prefixed', 'standard_primed', 'biosemi16', 'biosemi32', 'biosemi64', 'biosemi128', 'biosemi160', 'biosemi256', 'easycap-M1', 'easycap-M10', 'easycap-M43', 'EGI_256', 'GSN-HydroCel-32', 'GSN-HydroCel-64_1.0', 'GSN-HydroCel-65_1.0', 'GSN-HydroCel-128', 'GSN-HydroCel-129', 'GSN-HydroCel-256', 'GSN-HydroCel-257', 'mgh60', 'mgh70', 'artinis-octamon', 'artinis-brite23', 'brainproducts-RNP-BA-128']
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.
#
# 按字母排序后的通道数: 94
# ...

# %%
import json
import numpy as np
import mne

with open('paper_chs_pos.json', 'r', encoding='utf-8') as f:
    pos = json.load(f)
pos = {ch: np.array(coord) for ch, coord in pos.items()}
mont = mne.channels.make_dig_montage(ch_pos=pos, coord_frame='head')
# mont 可用于 raw.set_montage(mont) 或 mne.viz.plot_topomap(...)
print("montage ready")
# filepath: c:\Users\PS\Desktop\z7zb\脑电地势图\load_paper_chs_example.py
import json
import numpy as np
import mne

with open('paper_chs_pos.json', 'r', encoding='utf-8') as f:
    pos = json.load(f)
pos = {ch: np.array(coord) for ch, coord in pos.items()}
mont = mne.channels.make_dig_montage(ch_pos=pos, coord_frame='head')
# mont 可用于 raw.set_montage(mont) 或 mne.viz.plot_topomap(...)
print("montage ready")
mont.plot()
ch=['Fp1', 'Fp2', 'AF7', 'AF3', 'AFz', 'AF4', 'AF8', 'F7', 'F5', 'F3', 'F1', 'F2', 'F4', 'F6', 'F8', 'FT9', 'FT7', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'FT8', 'FT10','T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP9', 'TP7', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'TP8', 'TP10','P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO3', 'POz', 'PO4', 'PO8', 'O1', 'Oz', 'O2']
wg=[0.17101142, 0.15914118, 0.13442197, 0.13691998, 0.1252194, 0.12167193, 0.11950259, 0.08607113, 0.10182062, 0.11392317, 0.1243727, 0.12680698, 0.10257653, 0.11217174, 0.13617523, 0.12953414, 0.11885743, 0.11590699, 0.12518804, 0.12741049, 0.13108449, 0.13093963, 0.16658504, 0.13052203, 0.15554702, 0.23194983, 0.1962767, 0.22489029, 0.19625349, 0.16571625, 0.1868201, 0.17704289, 0.19594546, 0.21575786, 0.24795798, 0.40618575, 0.29500158, 0.25946576, 0.23279919, 0.20324002, 0.22194798, 0.21408635, 0.21512645, 0.29792428, 0.41179231, 0.37285111, 0.60093073, 0.52456132, 0.32902304, 0.33787858, 0.30875095, 0.27975434, 0.33103047, 0.56995374, 0.40837215, 0.610914, 0.57477059, 0.53290118, 0.49643639, 0.68217204, 0.54850834, 1.0, 0.58206334]
# Out:
# montage ready
# montage ready

# %%
import mne
import matplotlib.pyplot as plt

# 创建标准10-20系统的蒙太奇
import json
import numpy as np
import mne
# 读取MNE中biosemi64电极位置信息
biosemi_montage = mne.channels.make_standard_montage('biosemi64')
sensor_data_64 = biosemi_montage.get_positions()['ch_pos']
sensor_dataframe_64 = pd.DataFrame(sensor_data_64).T
chLa_index_64 = sensor_dataframe_64.index.values

with open('paper_chs_pos.json', 'r', encoding='utf-8') as f:
    pos = json.load(f)
pos = {ch: np.array(coord) for ch, coord in pos.items()}
mont = mne.channels.make_dig_montage(ch_pos=pos, coord_frame='head')
# mont 可用于 raw.set_montage(mont) 或 mne.viz.plot_topomap(...)
print("montage ready")
# filepath: c:\Users\PS\Desktop\z7zb\脑电地势图\load_paper_chs_example.py
import json
import numpy as np
import mne

with open('paper_chs_pos.json', 'r', encoding='utf-8') as f:
    pos = json.load(f)
pos = {ch: np.array(coord) for ch, coord in pos.items()}
mont = mne.channels.make_dig_montage(ch_pos=pos, coord_frame='head')
# mont 可用于 raw.set_montage(mont) 或 mne.viz.plot_topomap(...)
print("montage ready")
mont.plot()
standard_1020_montage = mont
standard_1020_montage.plot()
ch=['Fp1', 'Fp2', 'AF7', 'AF3', 'AFz', 'AF4', 'AF8', 'F7', 'F5', 'F3', 'F1', 'F2', 'F4', 'F6', 'F8', 'FT9', 'FT7', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'FT8', 'FT10','T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP9', 'TP7', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'TP8', 'TP10','P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO3', 'POz', 'PO4', 'PO8', 'O1', 'Oz', 'O2']
wg=[0.17101142, 0.15914118, 0.13442197, 0.13691998, 0.1252194, 0.12167193, 0.11950259, 0.08607113, 0.10182062, 0.11392317, 0.1243727, 0.12680698, 0.10257653, 0.11217174, 0.13617523, 0.12953414, 0.11885743, 0.11590699, 0.12518804, 0.12741049, 0.13108449, 0.13093963, 0.16658504, 0.13052203, 0.15554702, 0.23194983, 0.1962767, 0.22489029, 0.19625349, 0.16571625, 0.1868201, 0.17704289, 0.19594546, 0.21575786, 0.24795798, 0.40618575, 0.29500158, 0.25946576, 0.23279919, 0.20324002, 0.22194798, 0.21408635, 0.21512645, 0.29792428, 0.41179231, 0.37285111, 0.60093073, 0.52456132, 0.32902304, 0.33787858, 0.30875095, 0.27975434, 0.33103047, 0.56995374, 0.40837215, 0.610914, 0.57477059, 0.53290118, 0.49643639, 0.68217204, 0.54850834, 1.0, 0.58206334]

import mne
import numpy as np
import matplotlib.pyplot as plt
  


ch_names,mydata=ch,wg
montage = mne.channels.make_standard_montage('standard_1020')

info = mne.create_info(ch_names, sfreq=250, ch_types='eeg')


np.random.seed(4)
data = np.random.randn(len(ch_names), 1)  

data[:,0]=mydata
print(data.shape)  
# 
raw = mne.io.RawArray(data, info)

# 
raw.set_montage(montage)

# 绘制脑电地形图
time_point = 0  # 选择时间点
fig, ax = plt.subplots()
im, _ = mne.viz.plot_topomap(raw.get_data()[:, time_point], pos=raw.info,names = chLa_index_64, axes=ax, show=False,  cmap='coolwarm', vlim=(0, 1) )

plt.show()
# Out:
# montage ready
# montage ready
# (63, 1)
# Creating RawArray with float64 data, n_channels=63, n_times=1
#     Range : 0 ... 0 =      0.000 ...     0.000 secs
# Ready.
